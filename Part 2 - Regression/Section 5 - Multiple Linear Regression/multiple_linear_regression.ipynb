# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('50_Startups.csv')
X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, 4].values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelEncoder_X = LabelEncoder()
X[:,3] = labelEncoder_X.fit_transform(X[:,3])
oneHotEncoder = OneHotEncoder(categorical_features = [3])
print(OneHotEncoder(categorical_features = [3]))
X = oneHotEncoder.fit_transform(X).toarray()
print(X)
# Avoiding the dummy variable trap
X = X[:, 1:]
print(X)
# Out:
# OneHotEncoder(categorical_features=[3], dtype=<class 'numpy.float64'>,
#        handle_unknown='error', n_values='auto', sparse=True)
# [[  0.00000000e+00   0.00000000e+00   1.00000000e+00   1.65349200e+05
#     1.36897800e+05   4.71784100e+05]
#  [  1.00000000e+00   0.00000000e+00   0.00000000e+00   1.62597700e+05
#     1.51377590e+05   4.43898530e+05]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   1.53441510e+05
#     1.01145550e+05   4.07934540e+05]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00   1.44372410e+05
#     1.18671850e+05   3.83199620e+05]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   1.42107340e+05
#     9.13917700e+04   3.66168420e+05]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00   1.31876900e+05
#     9.98147100e+04   3.62861360e+05]
#  [  1.00000000e+00   0.00000000e+00   0.00000000e+00   1.34615460e+05
#     1.47198870e+05   1.27716820e+05]
#  [  0.00000000e+00   1.00000000e+00   0.00000000e+00   1.30298130e+05
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print(X_test)
# Out:
# [[  1.00000000e+00   0.00000000e+00   6.60515200e+04   1.82645560e+05
#     1.18148200e+05]
#  [  0.00000000e+00   0.00000000e+00   1.00671960e+05   9.17906100e+04
#     2.49744550e+05]
#  [  1.00000000e+00   0.00000000e+00   1.01913080e+05   1.10594110e+05
#     2.29160950e+05]
#  [  1.00000000e+00   0.00000000e+00   2.78929200e+04   8.47107700e+04
#     1.64470710e+05]
#  [  1.00000000e+00   0.00000000e+00   1.53441510e+05   1.01145550e+05
#     4.07934540e+05]
#  [  0.00000000e+00   1.00000000e+00   7.21076000e+04   1.27864550e+05
#     3.53183810e+05]
#  [  0.00000000e+00   1.00000000e+00   2.02295900e+04   6.59479300e+04
#     1.85265100e+05]
#  [  0.00000000e+00   1.00000000e+00   6.11363800e+04   1.52701920e+05
#     8.82182300e+04]
#  [  1.00000000e+00   0.00000000e+00   7.39945600e+04   1.22782750e+05
#     3.03319260e+05]
#  [  1.00000000e+00   0.00000000e+00   1.42107340e+05   9.13917700e+04
#     3.66168420e+05]]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_pred = regressor.predict(X_test)
print(Y_pred)
# Out:
# [ 103015.20159796  132582.27760815  132447.73845175   71976.09851258
#   178537.48221056  116161.24230166   67851.69209676   98791.73374687
#   113969.43533013  167921.06569551]

# %%
#Building the backward elimination method
#we need to add a column of 1 at the beginning of the matrix X, because this library that we will be using
#does not consider the b0 of the equation automatically
import statsmodels.api as sm
X = np.append(arr = np.ones((50,1)).astype(int), values=X, axis=1)

# %%
def OLS(a, b):
    regressor_OLS = sm.OLS(a, b).fit()
    print(regressor_OLS.summary())

# %%
X_opt = X[:,[0,1,2,3,4,5]]
regressor_OLS = sm.OLS(Y, X_opt).fit()
OLS(Y, X_opt)
X_opt = X[:, [0,1,3,4,5]]
OLS(Y, X_opt)
X_opt = X[:, [0,3,4,5]]
OLS(Y, X_opt)
X_opt = X[:, [0,3,5]]
OLS(Y, X_opt)
X_opt = X[:, [0,3]]
OLS(Y, X_opt)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Sun, 23 Apr 2017   Prob (F-statistic):           1.34e-27
# Time:                        02:57:24   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000      3.62e+04   6.4e+04
# ...
