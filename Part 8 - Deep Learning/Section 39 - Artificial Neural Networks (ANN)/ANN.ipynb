# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:,3:13].values
Y = dataset.iloc[:,13].values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelEncoder_X1 = LabelEncoder()
X[:,1] = labelEncoder_X1.fit_transform(X[:,1])
labelEncoder_X2 = LabelEncoder()
X[:,2] = labelEncoder_X2.fit_transform(X[:,2])
oneHotEncoder = OneHotEncoder(categorical_features = [1])
X = oneHotEncoder.fit_transform(X).toarray()
X = X[:,1:]
print(X)
# Out:
# [[  0.00000000e+00   0.00000000e+00   6.19000000e+02 ...,   1.00000000e+00
#     1.00000000e+00   1.01348880e+05]
#  [  0.00000000e+00   1.00000000e+00   6.08000000e+02 ...,   0.00000000e+00
#     1.00000000e+00   1.12542580e+05]
#  [  0.00000000e+00   0.00000000e+00   5.02000000e+02 ...,   1.00000000e+00
#     0.00000000e+00   1.13931570e+05]
#  ...,
#  [  0.00000000e+00   0.00000000e+00   7.09000000e+02 ...,   0.00000000e+00
#     1.00000000e+00   4.20855800e+04]
#  [  1.00000000e+00   0.00000000e+00   7.72000000e+02 ...,   1.00000000e+00
#     0.00000000e+00   9.28885200e+04]
#  [  0.00000000e+00   0.00000000e+00   7.92000000e+02 ...,   1.00000000e+00
#     0.00000000e+00   3.81907800e+04]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
print(X_test)
# Out:
# [[ 1.75486502 -0.57369368 -0.55204276 ...,  0.64259497  0.9687384
#    1.61085707]
#  [-0.5698444  -0.57369368 -1.31490297 ...,  0.64259497 -1.03227043
#    0.49587037]
#  [-0.5698444   1.74309049  0.57162971 ...,  0.64259497  0.9687384
#   -0.42478674]
#  ...,
#  [-0.5698444   1.74309049 -0.74791227 ...,  0.64259497 -1.03227043
#    0.71888467]
#  [ 1.75486502 -0.57369368 -0.00566991 ...,  0.64259497  0.9687384
#   -1.54507805]
#  [ 1.75486502 -0.57369368 -0.79945688 ...,  0.64259497 -1.03227043
#    1.61255917]]

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
classifier = Sequential()
classifier.add(Dense(activation='relu', input_dim=11, units=6, kernel_initializer='uniform'))
classifier.add(Dense(activation='relu', input_dim=11, units=6, kernel_initializer='uniform'))
classifier.add(Dense(activation='sigmoid', units=1, kernel_initializer='uniform'))

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
classifier.fit(X_train, Y_train, batch_size=5, epochs=100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 3s - loss: 0.4000 - acc: 0.8354
# Epoch 2/100
# 8000/8000 [==============================] - 3s - loss: 0.3997 - acc: 0.8356
# Epoch 3/100
# 8000/8000 [==============================] - 3s - loss: 0.3999 - acc: 0.8339
# Epoch 4/100
# 8000/8000 [==============================] - 3s - loss: 0.3999 - acc: 0.8369
# Epoch 5/100
# 8000/8000 [==============================] - 3s - loss: 0.3996 - acc: 0.8355
# Epoch 6/100
# 8000/8000 [==============================] - 3s - loss: 0.3997 - acc: 0.8356
# Epoch 7/100
# 8000/8000 [==============================] - 3s - loss: 0.3995 - acc: 0.8351
# Epoch 8/100
# 8000/8000 [==============================] - 3s - loss: 0.3996 - acc: 0.8336
# Epoch 9/100
# 8000/8000 [==============================] - 3s - loss: 0.3997 - acc: 0.8348
# Epoch 10/100
# 8000/8000 [==============================] - 3s - loss: 0.3999 - acc: 0.8351
# Epoch 11/100
# 8000/8000 [==============================] - 3s - loss: 0.3994 - acc: 0.8353
# Epoch 12/100
# 8000/8000 [==============================] - 2s - loss: 0.4001 - acc: 0.8358
# Epoch 13/100
# 8000/8000 [==============================] - 2s - loss: 0.3993 - acc: 0.8338
# Epoch 14/100
# 8000/8000 [==============================] - 2s - loss: 0.3998 - acc: 0.8353
# Epoch 15/100
# 8000/8000 [==============================] - 3s - loss: 0.3998 - acc: 0.8350
# Epoch 16/100
# 8000/8000 [==============================] - 3s - loss: 0.3992 - acc: 0.8361
# Epoch 17/100
# 8000/8000 [==============================] - 2s - loss: 0.3997 - acc: 0.8353
# Epoch 18/100
# 8000/8000 [==============================] - 3s - loss: 0.3997 - acc: 0.8343
# Epoch 19/100
#  - ETA: 1s - loss: 0.4515 - acc: 0.7967
# Epoch 20/100
# 8000/8000 [==============================] - 3s - loss: 0.3996 - acc: 0.8365
# Epoch 21/100
# 8000/8000 [==============================] - 3s - loss: 0.3995 - acc: 0.8368
# Epoch 22/100
# 8000/8000 [==============================] - 3s - loss: 0.3997 - acc: 0.8351
# Epoch 23/100
# 8000/8000 [==============================] - 2s - loss: 0.3995 - acc: 0.8355
# Epoch 24/100
# 8000/8000 [==============================] - 4s - loss: 0.3995 - acc: 0.8350
# Epoch 25/100
# 8000/8000 [==============================] - 3s - loss: 0.3993 - acc: 0.8354
# Epoch 26/100
# 8000/8000 [==============================] - 2s - loss: 0.3991 - acc: 0.8360
# Epoch 27/100
# 8000/8000 [==============================] - 3s - loss: 0.3974 - acc: 0.8364
# Epoch 28/100
# 8000/8000 [==============================] - 3s - loss: 0.3914 - acc: 0.8384
# Epoch 29/100
# 8000/8000 [==============================] - 2s - loss: 0.3788 - acc: 0.8441
# Epoch 30/100
# 8000/8000 [==============================] - 3s - loss: 0.3648 - acc: 0.8521
# Epoch 31/100
# 8000/8000 [==============================] - 3s - loss: 0.3561 - acc: 0.8549
# Epoch 32/100
# 8000/8000 [==============================] - 3s - loss: 0.3520 - acc: 0.8560
# Epoch 33/100
# 8000/8000 [==============================] - 3s - loss: 0.3499 - acc: 0.8564
# Epoch 34/100
# 8000/8000 [==============================] - 2s - loss: 0.3489 - acc: 0.8588
# Epoch 35/100
# 8000/8000 [==============================] - 2s - loss: 0.3479 - acc: 0.8581
# Epoch 36/100
# 8000/8000 [==============================] - 3s - loss: 0.3476 - acc: 0.8578
# Epoch 37/100
# 8000/8000 [==============================] - 3s - loss: 0.3471 - acc: 0.8579
# Epoch 38/100
# 2065/8000 [======>.......................] - ETA: 2s - loss: 0.3205 - acc: 0.8702

# %%
Y_pred = classifier.predict(X_test)
Y_pred = (Y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_pred)
print(cm)
# Out:
# [[1530   65]
#  [ 204  201]]

# %%
(1530+201)/2000
# Out:
# 0.8655
